# %%
# %%bash
# $HOME/usr/bin/jpscore ini_jpscore.xml
# Out:
# [2020-04-30 17:39:46.987] [info] Starting JuPedSim - JPScore
# [2020-04-30 17:39:46.987] [info] Version 0.8.4
# [2020-04-30 17:39:46.987] [info] Commit id v0.8.4-958-g263687e2
# [2020-04-30 17:39:46.987] [info] Commit date Tue Apr 28 11:25:58 2020
# [2020-04-30 17:39:46.987] [info] Build from branch master
# [2020-04-30 17:39:46.987] [info] Build with g++(9.3.0)
# [2020-04-30 17:39:46.987] [info] Loading and parsing the project file <ini_jpscore.xml>
# [2020-04-30 17:39:46.988] [info] Random seed <1254>
# [2020-04-30 17:39:46.988] [info] Maximal simulation time <200.00> seconds
# [2020-04-30 17:39:46.988] [info] Geometry file <geometry.xml>
# [2020-04-30 17:39:46.988] [info] Using 1 OpenMP threads, 1 available.
# [2020-04-30 17:39:46.988] [info] Output Path configured </home/mchraibi/results>
# [2020-04-30 17:39:46.988] [info] Output file  </home/mchraibi/results/trajectories.txt>
# [2020-04-30 17:39:46.988] [info] In format <plain> at <8> frames per seconds
# ...

# %%
# %%bash
# $HOME/usr/bin/jpsreport ini_jpsreport.xml
# Out:
# ----
# JuPedSim - JPSreport
#
# Current date   : Thu Apr 30 17:40:22 2020
# Version        : 0.8.4
# Compiler       : g++ (9.3.0)
# Commit hash    : v0.8.4-958-g263687e2
# Commit date    : Tue Apr 28 11:25:58 2020
# Branch         : master
# INFO: 	Parsing the ini file <ini_jpsreport.xml>
# INFO:	logfile </home/mchraibi/log.txt>
# INFO:	Success with Method D using measurement area id 1
# INFO: 	End Analysis for the file: trajectories.txt
# Time elapsed:	 32.5154 [s]
